# %%
# %matplotlib inline
from __future__ import print_function
import keras
from keras.layers import Input, Conv1D, MaxPooling2D, GlobalMaxPooling1D
from keras.layers.core import Dense, Activation
from keras.models import Sequential, Model
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

train_path = '/home/sillycat/Programming/Python/data_test/Good_registrations/Apr_ref/Apr23_A1_ref.npz'
test_path = '/home/sillycat/Programming/Python/data_test/Good_registrations/Apr_ref/Apr23_A3_ref.npz'
data_train = np.load(train_path)
data_test = np.load(test_path)
signal_train = data_train['signal'].T
NC, NT = signal_train.shape
label_train = np.zeros(NC)

# %%
'''
Manually label the first 100 neurons
'''

for ii in np.arange(180,200):
    plt.plot(signal_train[ii])
    plt.show()
    label_train[ii] = input("label the type of signal -- -1:ugly, 0:bad,1:good.")
# Out:
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.1
# label the type of signal -- -1:ugly, 0:bad,1:good.-1
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.-1
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.-1
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.-1
# label the type of signal -- -1:ugly, 0:bad,1:good.-1
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# label the type of signal -- -1:ugly, 0:bad,1:good.0
# ...

# %%
'''
Let's create a training data.
'''
def one_hot_encode_object_array(arr):
    '''One hot encode a numpy array of objects (e.g. strings)'''
    uniques, ids = np.unique(arr, return_inverse=True)
    return np_utils.to_categorical(ids, len(uniques))

Ncut = 200

X_train, X_test, Y_train, Y_test = train_test_split(signal_train[:Ncut], label_train[:Ncut], train_size = 0.2, test_size = 0.8, random_state = 0)
print(X_train.shape)
print(Y_train.shape)

cat_train = one_hot_encode_object_array(Y_train)
print(cat_train.shape)


model = Sequential()
model.add(Dense(16, input_shape = (1785,)))
model.add(Activation('relu'))
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(3))
model.add(Activation('softmax'))
b
# Out:
# (40, 1785)
# (40,)
# (40, 3)

# %%
cat_test = one_hot_encode_object_array(Y_test)
loss, accuracy = model.evaluate(X_test, cat_test, verbose=0)
print(loss)
print("Accuracy = {:.2f}".format(accuracy))
# Out:
# 1.083837366104126
# Accuracy = 0.64

# %%
model_cv = Sequential()
model_cv.add(Conv1D(filters = 250,
                 kernel_size = 3,
                 padding='valid',
                 activation='relu',
                 strides=1, input_shape = (1785,1)))
# we use max pooling:
model.add(GlobalMaxPooling1D())

# We add a vanilla hidden layer:
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Activation('relu'))

# We project onto a single unit output layer, and squash it with a sigmoid:
model.add(Dense(3))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
model.fit(X_train, cat_train, epochs=10, batch_size=1, verbose=0);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-6368464356b4> in <module>()
#       6                  strides=1, input_shape = (1785,1)))
#       7 # we use max pooling:
# ----> 8 model.add(GlobalMaxPooling1D())
#       9
#      10 # We add a vanilla hidden layer:
#
# NameError: name 'GlobalMaxPooling1D' is not defined
